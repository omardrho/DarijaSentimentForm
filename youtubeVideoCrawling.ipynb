# %% [markdown]
# <a href="https://colab.research.google.com/github/omardrho/DarijaSentimentForm/blob/master/youtubeVideoCrawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client pandas

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
api_key = 'AIzaSyCAyePluw95z8diqa8AvravqVsY93DEHMk'
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
channel_id = 'UC8butISFwT-Wl7EV0hUK0BQ'
video_count = 20
part = 'snippet,statistics'

# %%
search_params = {
    # 'q': 'YOUR_SEARCH_QUERY_HERE',
    'type': 'video',
    'part': 'id,snippet',
    'maxResults': 50,
    'order': 'date',
    'channelId' : channel_id
}

# %%
response = youtube.search().list(**search_params).execute()
video_ids = [item['id']['videoId'] for item in response['items']]

# %%
response = youtube.videos().list(
    part=part,
    id=','.join(video_ids)
).execute()

# %%
data = []
for item in sorted(response['items'], key=lambda x: x['snippet']['publishedAt'], reverse=True):
    video_data = {
        'Title': item['snippet']['title'],
        'url': f"https://www.youtube.com/watch?v={item['id']}",
        'Description': item['snippet']['description'],
        'View Count': item['statistics']['viewCount'],
        'Likes' :item['statistics']['likeCount'],
        'Published At': item['snippet']['publishedAt']
    }
    data.append(video_data)

df = pd.DataFrame(data)

# %%
df
# Out:
#                                             url  \
# 0   https://www.youtube.com/watch?v=VCayKl82Lt8
# 1   https://www.youtube.com/watch?v=1WpKsY9LBlY
# 2   https://www.youtube.com/watch?v=nVhau51w6dM
# 3   https://www.youtube.com/watch?v=YT8s-90oDC0
# 4   https://www.youtube.com/watch?v=gtjxAH8uaP0
# 5   https://www.youtube.com/watch?v=MIL2BK02X8A
# 6   https://www.youtube.com/watch?v=BpPEoZW5IiY
# 7   https://www.youtube.com/watch?v=IA3WxTTPXqQ
# 8   https://www.youtube.com/watch?v=_IgbB24scLI
# 9   https://www.youtube.com/watch?v=jlogLBkPZ2A
# 10  https://www.youtube.com/watch?v=qrZGfBBlXpk
# 11  https://www.youtube.com/watch?v=FRmCxj9K7II
# 12  https://www.youtube.com/watch?v=GizsSo-EevA
# 13  https://www.youtube.com/watch?v=ypNKKYUJE5o
# 14  https://www.youtube.com/watch?v=K7ghUiXLef8
# 15  https://www.youtube.com/watch?v=un6ZyFkqFKo
# 16  https://www.youtube.com/watch?v=-fW2X7fh7Yg
# 17  https://www.youtube.com/watch?v=n3tA3Ku65_8
# ...

# %%
df.shape
